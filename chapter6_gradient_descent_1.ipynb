# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np

# %%
target = torch.FloatTensor([i * 0.1 + 0.1 for i in range(9)]).reshape(3, 3)
target
# Out:
# tensor([[0.1000, 0.2000, 0.3000],
#         [0.4000, 0.5000, 0.6000],
#         [0.7000, 0.8000, 0.9000]])

# %%
X = torch.rand_like(target)
X.requires_grad = True

# %%
X
# Out:
# tensor([[0.8326, 0.4895, 0.7254],
#         [0.4519, 0.9958, 0.5701],
#         [0.2889, 0.0670, 0.3210]], requires_grad=True)

# %%
loss = F.mse_loss(X, target)
loss
# Out:
# tensor(0.2325, grad_fn=<MseLossBackward0>)

# %%
thres = 1e-5
lr = 0.1
iter_cnt = 0

# %%
while loss > thres:
    iter_cnt += 1
    loss.backward()
    X = X - lr * X.grad
    X.detach_()
    X.requires_grad_(True)
    loss = F.mse_loss(X, target)
    print(X)
    print(loss)
# Out:
# tensor([[0.8163, 0.4830, 0.7159],
#         [0.4508, 0.9847, 0.5707],
#         [0.2980, 0.0833, 0.3338]], requires_grad=True)
# tensor(0.2223, grad_fn=<MseLossBackward0>)
# tensor([[0.8004, 0.4767, 0.7067],
#         [0.4496, 0.9740, 0.5714],
#         [0.3069, 0.0992, 0.3464]], requires_grad=True)
# tensor(0.2125, grad_fn=<MseLossBackward0>)
# tensor([[0.7848, 0.4706, 0.6977],
#         [0.4485, 0.9634, 0.5720],
#         [0.3157, 0.1148, 0.3587]], requires_grad=True)
# tensor(0.2032, grad_fn=<MseLossBackward0>)
# tensor([[0.7696, 0.4646, 0.6888],
#         [0.4475, 0.9531, 0.5726],
#         [0.3242, 0.1300, 0.3707]], requires_grad=True)
# tensor(0.1942, grad_fn=<MseLossBackward0>)
# tensor([[0.7547, 0.4587, 0.6802],
#         [0.4464, 0.9431, 0.5732],
#         [0.3326, 0.1449, 0.3825]], requires_grad=True)
# tensor(0.1857, grad_fn=<MseLossBackward0>)
# tensor([[0.7402, 0.4529, 0.6717],
#         [0.4454, 0.9332, 0.5738],
#         [0.3407, 0.1594, 0.3940]], requires_grad=True)
# tensor(0.1775, grad_fn=<MseLossBackward0>)
# tensor([[0.7259, 0.4473, 0.6635],
#         [0.4444, 0.9236, 0.5744],
#         [0.3487, 0.1737, 0.4052]], requires_grad=True)
# tensor(0.1697, grad_fn=<MseLossBackward0>)
# tensor([[0.7120, 0.4418, 0.6554],
#         [0.4434, 0.9142, 0.5750],
#         [0.3565, 0.1876, 0.4162]], requires_grad=True)
# tensor(0.1623, grad_fn=<MseLossBackward0>)
# tensor([[0.6984, 0.4365, 0.6475],
#         [0.4424, 0.9050, 0.5755],
#         [0.3642, 0.2012, 0.4270]], requires_grad=True)
# tensor(0.1551, grad_fn=<MseLossBackward0>)
# tensor([[0.6851, 0.4312, 0.6398],
#         [0.4415, 0.8960, 0.5761],
#         [0.3716, 0.2145, 0.4375]], requires_grad=True)
# tensor(0.1483, grad_fn=<MseLossBackward0>)
# tensor([[0.6721, 0.4261, 0.6322],
#         [0.4405, 0.8872, 0.5766],
#         [0.3789, 0.2275, 0.4478]], requires_grad=True)
# tensor(0.1418, grad_fn=<MseLossBackward0>)
# tensor([[0.6594, 0.4210, 0.6248],
#         [0.4396, 0.8786, 0.5771],
#         [0.3860, 0.2402, 0.4578]], requires_grad=True)
# tensor(0.1356, grad_fn=<MseLossBackward0>)
# tensor([[0.6470, 0.4161, 0.6176],
#         [0.4388, 0.8702, 0.5776],
#         [0.3930, 0.2527, 0.4676]], requires_grad=True)
# tensor(0.1296, grad_fn=<MseLossBackward0>)
# tensor([[0.6348, 0.4113, 0.6106],
#         [0.4379, 0.8619, 0.5781],
#         [0.3998, 0.2648, 0.4773]], requires_grad=True)
# tensor(0.1239, grad_fn=<MseLossBackward0>)
# tensor([[0.6229, 0.4066, 0.6037],
#         [0.4371, 0.8539, 0.5786],
#         [0.4065, 0.2767, 0.4867]], requires_grad=True)
# tensor(0.1185, grad_fn=<MseLossBackward0>)
# tensor([[0.6113, 0.4020, 0.5969],
#         [0.4362, 0.8460, 0.5791],
#         [0.4130, 0.2884, 0.4958]], requires_grad=True)
# tensor(0.1133, grad_fn=<MseLossBackward0>)
# tensor([[0.6000, 0.3975, 0.5903],
#         [0.4354, 0.8383, 0.5796],
#         [0.4194, 0.2997, 0.5048]], requires_grad=True)
# tensor(0.1083, grad_fn=<MseLossBackward0>)
# tensor([[0.5889, 0.3932, 0.5839],
#         [0.4346, 0.8308, 0.5800],
#         [0.4257, 0.3108, 0.5136]], requires_grad=True)
# tensor(0.1035, grad_fn=<MseLossBackward0>)
# tensor([[0.5780, 0.3889, 0.5776],
#         [0.4339, 0.8235, 0.5805],
#         [0.4317, 0.3217, 0.5222]], requires_grad=True)
# tensor(0.0990, grad_fn=<MseLossBackward0>)
# tensor([[0.5674, 0.3847, 0.5714],
#         [0.4331, 0.8163, 0.5809],
#         [0.4377, 0.3323, 0.5306]], requires_grad=True)
# tensor(0.0946, grad_fn=<MseLossBackward0>)
# tensor([[0.5570, 0.3806, 0.5654],
#         [0.4324, 0.8093, 0.5813],
#         [0.4435, 0.3427, 0.5388]], requires_grad=True)
# tensor(0.0905, grad_fn=<MseLossBackward0>)
# tensor([[0.5468, 0.3765, 0.5595],
#         [0.4317, 0.8024, 0.5817],
#         [0.4492, 0.3529, 0.5468]], requires_grad=True)
# tensor(0.0865, grad_fn=<MseLossBackward0>)
# tensor([[0.5369, 0.3726, 0.5537],
#         [0.4310, 0.7957, 0.5821],
#         [0.4548, 0.3628, 0.5547]], requires_grad=True)
# tensor(0.0827, grad_fn=<MseLossBackward0>)
# tensor([[0.5272, 0.3688, 0.5481],
#         [0.4303, 0.7891, 0.5825],
#         [0.4603, 0.3725, 0.5623]], requires_grad=True)
# tensor(0.0791, grad_fn=<MseLossBackward0>)
# tensor([[0.5177, 0.3650, 0.5425],
#         [0.4296, 0.7827, 0.5829],
#         [0.4656, 0.3820, 0.5698]], requires_grad=True)
# tensor(0.0756, grad_fn=<MseLossBackward0>)
# tensor([[0.5084, 0.3614, 0.5372],
#         [0.4289, 0.7764, 0.5833],
#         [0.4708, 0.3913, 0.5772]], requires_grad=True)
# tensor(0.0723, grad_fn=<MseLossBackward0>)
# tensor([[0.4993, 0.3578, 0.5319],
#         [0.4283, 0.7702, 0.5837],
#         [0.4759, 0.4004, 0.5844]], requires_grad=True)
# tensor(0.0691, grad_fn=<MseLossBackward0>)
# tensor([[0.4905, 0.3543, 0.5267],
#         [0.4277, 0.7642, 0.5840],
#         [0.4809, 0.4093, 0.5914]], requires_grad=True)
# tensor(0.0660, grad_fn=<MseLossBackward0>)
# tensor([[0.4818, 0.3508, 0.5217],
#         [0.4271, 0.7584, 0.5844],
#         [0.4857, 0.4180, 0.5982]], requires_grad=True)
# tensor(0.0631, grad_fn=<MseLossBackward0>)
# tensor([[0.4733, 0.3475, 0.5168],
#         [0.4265, 0.7526, 0.5847],
#         [0.4905, 0.4265, 0.6049]], requires_grad=True)
# tensor(0.0604, grad_fn=<MseLossBackward0>)
# tensor([[0.4650, 0.3442, 0.5119],
#         [0.4259, 0.7470, 0.5851],
#         [0.4952, 0.4348, 0.6115]], requires_grad=True)
# tensor(0.0577, grad_fn=<MseLossBackward0>)
# tensor([[0.4569, 0.3410, 0.5072],
#         [0.4253, 0.7415, 0.5854],
#         [0.4997, 0.4429, 0.6179]], requires_grad=True)
# tensor(0.0552, grad_fn=<MseLossBackward0>)
# tensor([[0.4490, 0.3379, 0.5026],
#         [0.4247, 0.7362, 0.5857],
#         [0.5042, 0.4508, 0.6242]], requires_grad=True)
# tensor(0.0528, grad_fn=<MseLossBackward0>)
# tensor([[0.4412, 0.3348, 0.4981],
#         [0.4242, 0.7309, 0.5861],
#         [0.5085, 0.4586, 0.6303]], requires_grad=True)
# tensor(0.0504, grad_fn=<MseLossBackward0>)
# tensor([[0.4336, 0.3318, 0.4937],
#         [0.4236, 0.7258, 0.5864],
#         [0.5128, 0.4662, 0.6363]], requires_grad=True)
# tensor(0.0482, grad_fn=<MseLossBackward0>)
# tensor([[0.4262, 0.3289, 0.4894],
#         [0.4231, 0.7208, 0.5867],
#         [0.5169, 0.4736, 0.6422]], requires_grad=True)
# tensor(0.0461, grad_fn=<MseLossBackward0>)
# tensor([[0.4190, 0.3260, 0.4852],
#         [0.4226, 0.7159, 0.5870],
#         [0.5210, 0.4808, 0.6479]], requires_grad=True)
# tensor(0.0441, grad_fn=<MseLossBackward0>)
# tensor([[0.4119, 0.3232, 0.4811],
#         [0.4221, 0.7111, 0.5873],
#         [0.5250, 0.4879, 0.6535]], requires_grad=True)
# tensor(0.0421, grad_fn=<MseLossBackward0>)
# tensor([[0.4049, 0.3205, 0.4771],
#         [0.4216, 0.7064, 0.5875],
#         [0.5289, 0.4949, 0.6590]], requires_grad=True)
# tensor(0.0403, grad_fn=<MseLossBackward0>)
# tensor([[0.3982, 0.3178, 0.4731],
#         [0.4211, 0.7018, 0.5878],
#         [0.5327, 0.5016, 0.6643]], requires_grad=True)
# tensor(0.0385, grad_fn=<MseLossBackward0>)
# tensor([[0.3915, 0.3152, 0.4693],
#         [0.4207, 0.6973, 0.5881],
#         [0.5364, 0.5083, 0.6696]], requires_grad=True)
# tensor(0.0368, grad_fn=<MseLossBackward0>)
# tensor([[0.3851, 0.3126, 0.4655],
#         [0.4202, 0.6929, 0.5883],
#         [0.5400, 0.5148, 0.6747]], requires_grad=True)
# tensor(0.0352, grad_fn=<MseLossBackward0>)
# tensor([[0.3787, 0.3101, 0.4618],
#         [0.4198, 0.6886, 0.5886],
#         [0.5436, 0.5211, 0.6797]], requires_grad=True)
# tensor(0.0337, grad_fn=<MseLossBackward0>)
# tensor([[0.3725, 0.3077, 0.4583],
#         [0.4193, 0.6844, 0.5889],
#         [0.5471, 0.5273, 0.6846]], requires_grad=True)
# tensor(0.0322, grad_fn=<MseLossBackward0>)
# tensor([[0.3665, 0.3053, 0.4547],
#         [0.4189, 0.6803, 0.5891],
#         [0.5504, 0.5334, 0.6894]], requires_grad=True)
# tensor(0.0308, grad_fn=<MseLossBackward0>)
# tensor([[0.3606, 0.3029, 0.4513],
#         [0.4185, 0.6763, 0.5893],
#         [0.5538, 0.5393, 0.6941]], requires_grad=True)
# tensor(0.0294, grad_fn=<MseLossBackward0>)
# tensor([[0.3548, 0.3007, 0.4479],
#         [0.4181, 0.6724, 0.5896],
#         [0.5570, 0.5451, 0.6986]], requires_grad=True)
# tensor(0.0281, grad_fn=<MseLossBackward0>)
# tensor([[0.3491, 0.2984, 0.4446],
#         [0.4177, 0.6686, 0.5898],
#         [0.5602, 0.5507, 0.7031]], requires_grad=True)
# tensor(0.0269, grad_fn=<MseLossBackward0>)
# tensor([[0.3436, 0.2962, 0.4414],
#         [0.4173, 0.6648, 0.5900],
#         [0.5633, 0.5563, 0.7075]], requires_grad=True)
# tensor(0.0257, grad_fn=<MseLossBackward0>)
# tensor([[0.3382, 0.2941, 0.4383],
#         [0.4169, 0.6612, 0.5903],
#         [0.5663, 0.5617, 0.7118]], requires_grad=True)
# tensor(0.0246, grad_fn=<MseLossBackward0>)
# tensor([[0.3329, 0.2920, 0.4352],
#         [0.4165, 0.6576, 0.5905],
#         [0.5693, 0.5670, 0.7159]], requires_grad=True)
# tensor(0.0235, grad_fn=<MseLossBackward0>)
# tensor([[0.3277, 0.2900, 0.4322],
#         [0.4161, 0.6541, 0.5907],
#         [0.5722, 0.5722, 0.7200]], requires_grad=True)
# tensor(0.0225, grad_fn=<MseLossBackward0>)
# tensor([[0.3226, 0.2880, 0.4293],
#         [0.4158, 0.6507, 0.5909],
#         [0.5751, 0.5772, 0.7240]], requires_grad=True)
# tensor(0.0215, grad_fn=<MseLossBackward0>)
# tensor([[0.3177, 0.2860, 0.4264],
#         [0.4154, 0.6473, 0.5911],
#         [0.5778, 0.5822, 0.7279]], requires_grad=True)
# tensor(0.0205, grad_fn=<MseLossBackward0>)
# tensor([[0.3128, 0.2841, 0.4236],
#         [0.4151, 0.6440, 0.5913],
#         [0.5805, 0.5870, 0.7318]], requires_grad=True)
# tensor(0.0196, grad_fn=<MseLossBackward0>)
# tensor([[0.3081, 0.2822, 0.4208],
#         [0.4147, 0.6408, 0.5915],
#         [0.5832, 0.5918, 0.7355]], requires_grad=True)
# tensor(0.0188, grad_fn=<MseLossBackward0>)
# tensor([[0.3035, 0.2804, 0.4182],
#         [0.4144, 0.6377, 0.5917],
#         [0.5858, 0.5964, 0.7392]], requires_grad=True)
# tensor(0.0179, grad_fn=<MseLossBackward0>)
# tensor([[0.2990, 0.2786, 0.4155],
#         [0.4141, 0.6346, 0.5919],
#         [0.5883, 0.6009, 0.7427]], requires_grad=True)
# tensor(0.0172, grad_fn=<MseLossBackward0>)
# tensor([[0.2945, 0.2769, 0.4130],
#         [0.4138, 0.6317, 0.5920],
#         [0.5908, 0.6053, 0.7462]], requires_grad=True)
# tensor(0.0164, grad_fn=<MseLossBackward0>)
# tensor([[0.2902, 0.2752, 0.4105],
#         [0.4135, 0.6287, 0.5922],
#         [0.5932, 0.6097, 0.7496]], requires_grad=True)
# tensor(0.0157, grad_fn=<MseLossBackward0>)
# tensor([[0.2860, 0.2735, 0.4080],
#         [0.4132, 0.6259, 0.5924],
#         [0.5956, 0.6139, 0.7530]], requires_grad=True)
# tensor(0.0150, grad_fn=<MseLossBackward0>)
# tensor([[0.2819, 0.2719, 0.4056],
#         [0.4129, 0.6231, 0.5926],
#         [0.5979, 0.6180, 0.7563]], requires_grad=True)
# tensor(0.0143, grad_fn=<MseLossBackward0>)
# tensor([[0.2778, 0.2703, 0.4033],
#         [0.4126, 0.6203, 0.5927],
#         [0.6002, 0.6221, 0.7594]], requires_grad=True)
# tensor(0.0137, grad_fn=<MseLossBackward0>)
# tensor([[0.2739, 0.2687, 0.4010],
#         [0.4123, 0.6177, 0.5929],
#         [0.6024, 0.6260, 0.7626]], requires_grad=True)
# tensor(0.0131, grad_fn=<MseLossBackward0>)
# tensor([[0.2700, 0.2672, 0.3987],
#         [0.4120, 0.6150, 0.5931],
#         [0.6046, 0.6299, 0.7656]], requires_grad=True)
# tensor(0.0125, grad_fn=<MseLossBackward0>)
# tensor([[0.2662, 0.2657, 0.3965],
#         [0.4118, 0.6125, 0.5932],
#         [0.6067, 0.6337, 0.7686]], requires_grad=True)
# tensor(0.0120, grad_fn=<MseLossBackward0>)
# tensor([[0.2625, 0.2642, 0.3944],
#         [0.4115, 0.6100, 0.5934],
#         [0.6088, 0.6374, 0.7715]], requires_grad=True)
# tensor(0.0114, grad_fn=<MseLossBackward0>)
# tensor([[0.2589, 0.2628, 0.3923],
#         [0.4113, 0.6075, 0.5935],
#         [0.6108, 0.6410, 0.7744]], requires_grad=True)
# tensor(0.0109, grad_fn=<MseLossBackward0>)
# tensor([[0.2554, 0.2614, 0.3902],
#         [0.4110, 0.6052, 0.5936],
#         [0.6128, 0.6445, 0.7772]], requires_grad=True)
# tensor(0.0105, grad_fn=<MseLossBackward0>)
# tensor([[0.2519, 0.2600, 0.3882],
#         [0.4108, 0.6028, 0.5938],
#         [0.6147, 0.6480, 0.7799]], requires_grad=True)
# tensor(0.0100, grad_fn=<MseLossBackward0>)
# tensor([[0.2486, 0.2587, 0.3863],
#         [0.4105, 0.6005, 0.5939],
#         [0.6166, 0.6513, 0.7826]], requires_grad=True)
# tensor(0.0096, grad_fn=<MseLossBackward0>)
# tensor([[0.2453, 0.2574, 0.3843],
#         [0.4103, 0.5983, 0.5941],
#         [0.6185, 0.6546, 0.7852]], requires_grad=True)
# tensor(0.0091, grad_fn=<MseLossBackward0>)
# tensor([[0.2420, 0.2561, 0.3825],
#         [0.4101, 0.5961, 0.5942],
#         [0.6203, 0.6579, 0.7877]], requires_grad=True)
# tensor(0.0087, grad_fn=<MseLossBackward0>)
# tensor([[0.2389, 0.2549, 0.3806],
#         [0.4098, 0.5940, 0.5943],
#         [0.6221, 0.6610, 0.7902]], requires_grad=True)
# tensor(0.0084, grad_fn=<MseLossBackward0>)
# tensor([[0.2358, 0.2537, 0.3788],
#         [0.4096, 0.5919, 0.5944],
#         [0.6238, 0.6641, 0.7927]], requires_grad=True)
# tensor(0.0080, grad_fn=<MseLossBackward0>)
# tensor([[0.2328, 0.2525, 0.3771],
#         [0.4094, 0.5899, 0.5946],
#         [0.6255, 0.6671, 0.7951]], requires_grad=True)
# tensor(0.0076, grad_fn=<MseLossBackward0>)
# tensor([[0.2298, 0.2513, 0.3754],
#         [0.4092, 0.5879, 0.5947],
#         [0.6271, 0.6701, 0.7974]], requires_grad=True)
# tensor(0.0073, grad_fn=<MseLossBackward0>)
# tensor([[0.2269, 0.2502, 0.3737],
#         [0.4090, 0.5859, 0.5948],
#         [0.6288, 0.6730, 0.7997]], requires_grad=True)
# tensor(0.0070, grad_fn=<MseLossBackward0>)
# tensor([[0.2241, 0.2490, 0.3721],
#         [0.4088, 0.5840, 0.5949],
#         [0.6303, 0.6758, 0.8019]], requires_grad=True)
# tensor(0.0067, grad_fn=<MseLossBackward0>)
# tensor([[0.2214, 0.2480, 0.3705],
#         [0.4086, 0.5821, 0.5950],
#         [0.6319, 0.6786, 0.8041]], requires_grad=True)
# tensor(0.0064, grad_fn=<MseLossBackward0>)
# tensor([[0.2187, 0.2469, 0.3689],
#         [0.4084, 0.5803, 0.5951],
#         [0.6334, 0.6813, 0.8062]], requires_grad=True)
# tensor(0.0061, grad_fn=<MseLossBackward0>)
# tensor([[0.2160, 0.2458, 0.3674],
#         [0.4082, 0.5785, 0.5953],
#         [0.6349, 0.6839, 0.8083]], requires_grad=True)
# tensor(0.0058, grad_fn=<MseLossBackward0>)
# tensor([[0.2134, 0.2448, 0.3659],
#         [0.4080, 0.5768, 0.5954],
#         [0.6363, 0.6865, 0.8103]], requires_grad=True)
# tensor(0.0056, grad_fn=<MseLossBackward0>)
# tensor([[0.2109, 0.2438, 0.3644],
#         [0.4079, 0.5751, 0.5955],
#         [0.6377, 0.6890, 0.8123]], requires_grad=True)
# tensor(0.0053, grad_fn=<MseLossBackward0>)
# tensor([[0.2085, 0.2429, 0.3630],
#         [0.4077, 0.5734, 0.5956],
#         [0.6391, 0.6915, 0.8143]], requires_grad=True)
# tensor(0.0051, grad_fn=<MseLossBackward0>)
# tensor([[0.2060, 0.2419, 0.3616],
#         [0.4075, 0.5718, 0.5957],
#         [0.6405, 0.6939, 0.8162]], requires_grad=True)
# tensor(0.0049, grad_fn=<MseLossBackward0>)
# tensor([[0.2037, 0.2410, 0.3602],
#         [0.4073, 0.5702, 0.5958],
#         [0.6418, 0.6962, 0.8180]], requires_grad=True)
# tensor(0.0047, grad_fn=<MseLossBackward0>)
# tensor([[0.2014, 0.2401, 0.3589],
#         [0.4072, 0.5686, 0.5959],
#         [0.6431, 0.6985, 0.8199]], requires_grad=True)
# tensor(0.0045, grad_fn=<MseLossBackward0>)
# tensor([[0.1991, 0.2392, 0.3576],
#         [0.4070, 0.5671, 0.5959],
#         [0.6444, 0.7008, 0.8216]], requires_grad=True)
# tensor(0.0043, grad_fn=<MseLossBackward0>)
# tensor([[0.1969, 0.2383, 0.3563],
#         [0.4069, 0.5656, 0.5960],
#         [0.6456, 0.7030, 0.8234]], requires_grad=True)
# tensor(0.0041, grad_fn=<MseLossBackward0>)
# tensor([[0.1948, 0.2374, 0.3550],
#         [0.4067, 0.5641, 0.5961],
#         [0.6468, 0.7052, 0.8251]], requires_grad=True)
# tensor(0.0039, grad_fn=<MseLossBackward0>)
# tensor([[0.1927, 0.2366, 0.3538],
#         [0.4066, 0.5627, 0.5962],
#         [0.6480, 0.7073, 0.8267]], requires_grad=True)
# tensor(0.0037, grad_fn=<MseLossBackward0>)
# tensor([[0.1906, 0.2358, 0.3526],
#         [0.4064, 0.5613, 0.5963],
#         [0.6491, 0.7093, 0.8284]], requires_grad=True)
# tensor(0.0036, grad_fn=<MseLossBackward0>)
# tensor([[0.1886, 0.2350, 0.3514],
#         [0.4063, 0.5600, 0.5964],
#         [0.6503, 0.7113, 0.8300]], requires_grad=True)
# tensor(0.0034, grad_fn=<MseLossBackward0>)
# tensor([[0.1866, 0.2342, 0.3503],
#         [0.4061, 0.5586, 0.5965],
#         [0.6514, 0.7133, 0.8315]], requires_grad=True)
# tensor(0.0033, grad_fn=<MseLossBackward0>)
# tensor([[0.1847, 0.2335, 0.3492],
#         [0.4060, 0.5573, 0.5965],
#         [0.6525, 0.7152, 0.8330]], requires_grad=True)
# tensor(0.0031, grad_fn=<MseLossBackward0>)
# tensor([[0.1828, 0.2327, 0.3481],
#         [0.4059, 0.5560, 0.5966],
#         [0.6535, 0.7171, 0.8345]], requires_grad=True)
# tensor(0.0030, grad_fn=<MseLossBackward0>)
# tensor([[0.1810, 0.2320, 0.3470],
#         [0.4057, 0.5548, 0.5967],
#         [0.6546, 0.7190, 0.8360]], requires_grad=True)
# tensor(0.0028, grad_fn=<MseLossBackward0>)
# tensor([[0.1792, 0.2313, 0.3460],
#         [0.4056, 0.5536, 0.5968],
#         [0.6556, 0.7208, 0.8374]], requires_grad=True)
# tensor(0.0027, grad_fn=<MseLossBackward0>)
# tensor([[0.1774, 0.2306, 0.3450],
#         [0.4055, 0.5524, 0.5968],
#         [0.6565, 0.7225, 0.8388]], requires_grad=True)
# tensor(0.0026, grad_fn=<MseLossBackward0>)
# tensor([[0.1757, 0.2299, 0.3440],
#         [0.4054, 0.5512, 0.5969],
#         [0.6575, 0.7243, 0.8402]], requires_grad=True)
# tensor(0.0025, grad_fn=<MseLossBackward0>)
# tensor([[0.1740, 0.2292, 0.3430],
#         [0.4052, 0.5501, 0.5970],
#         [0.6585, 0.7259, 0.8415]], requires_grad=True)
# tensor(0.0024, grad_fn=<MseLossBackward0>)
# tensor([[0.1724, 0.2286, 0.3420],
#         [0.4051, 0.5490, 0.5970],
#         [0.6594, 0.7276, 0.8428]], requires_grad=True)
# tensor(0.0023, grad_fn=<MseLossBackward0>)
# tensor([[0.1708, 0.2280, 0.3411],
#         [0.4050, 0.5479, 0.5971],
#         [0.6603, 0.7292, 0.8441]], requires_grad=True)
# tensor(0.0022, grad_fn=<MseLossBackward0>)
# tensor([[0.1692, 0.2273, 0.3402],
#         [0.4049, 0.5468, 0.5972],
#         [0.6612, 0.7308, 0.8453]], requires_grad=True)
# tensor(0.0021, grad_fn=<MseLossBackward0>)
# tensor([[0.1677, 0.2267, 0.3393],
#         [0.4048, 0.5458, 0.5972],
#         [0.6620, 0.7323, 0.8465]], requires_grad=True)
# tensor(0.0020, grad_fn=<MseLossBackward0>)
# tensor([[0.1662, 0.2261, 0.3384],
#         [0.4047, 0.5448, 0.5973],
#         [0.6629, 0.7338, 0.8477]], requires_grad=True)
# tensor(0.0019, grad_fn=<MseLossBackward0>)
# tensor([[0.1647, 0.2256, 0.3376],
#         [0.4046, 0.5438, 0.5974],
#         [0.6637, 0.7353, 0.8489]], requires_grad=True)
# tensor(0.0018, grad_fn=<MseLossBackward0>)
# tensor([[0.1632, 0.2250, 0.3367],
#         [0.4045, 0.5428, 0.5974],
#         [0.6645, 0.7367, 0.8500]], requires_grad=True)
# tensor(0.0017, grad_fn=<MseLossBackward0>)
# tensor([[0.1618, 0.2244, 0.3359],
#         [0.4044, 0.5418, 0.5975],
#         [0.6653, 0.7381, 0.8511]], requires_grad=True)
# tensor(0.0017, grad_fn=<MseLossBackward0>)
# tensor([[0.1605, 0.2239, 0.3351],
#         [0.4043, 0.5409, 0.5975],
#         [0.6661, 0.7395, 0.8522]], requires_grad=True)
# tensor(0.0016, grad_fn=<MseLossBackward0>)
# tensor([[0.1591, 0.2234, 0.3343],
#         [0.4042, 0.5400, 0.5976],
#         [0.6668, 0.7408, 0.8533]], requires_grad=True)
# tensor(0.0015, grad_fn=<MseLossBackward0>)
# tensor([[0.1578, 0.2228, 0.3336],
#         [0.4041, 0.5391, 0.5976],
#         [0.6676, 0.7422, 0.8543]], requires_grad=True)
# tensor(0.0014, grad_fn=<MseLossBackward0>)
# tensor([[0.1565, 0.2223, 0.3328],
#         [0.4040, 0.5383, 0.5977],
#         [0.6683, 0.7434, 0.8553]], requires_grad=True)
# tensor(0.0014, grad_fn=<MseLossBackward0>)
# tensor([[0.1553, 0.2218, 0.3321],
#         [0.4039, 0.5374, 0.5977],
#         [0.6690, 0.7447, 0.8563]], requires_grad=True)
# tensor(0.0013, grad_fn=<MseLossBackward0>)
# tensor([[0.1540, 0.2214, 0.3314],
#         [0.4038, 0.5366, 0.5978],
#         [0.6697, 0.7459, 0.8573]], requires_grad=True)
# tensor(0.0013, grad_fn=<MseLossBackward0>)
# tensor([[0.1528, 0.2209, 0.3307],
#         [0.4037, 0.5358, 0.5978],
#         [0.6703, 0.7471, 0.8582]], requires_grad=True)
# tensor(0.0012, grad_fn=<MseLossBackward0>)
# tensor([[0.1517, 0.2204, 0.3300],
#         [0.4037, 0.5350, 0.5979],
#         [0.6710, 0.7483, 0.8592]], requires_grad=True)
# tensor(0.0012, grad_fn=<MseLossBackward0>)
# tensor([[0.1505, 0.2200, 0.3293],
#         [0.4036, 0.5342, 0.5979],
#         [0.6716, 0.7495, 0.8601]], requires_grad=True)
# tensor(0.0011, grad_fn=<MseLossBackward0>)
# tensor([[0.1494, 0.2195, 0.3287],
#         [0.4035, 0.5334, 0.5980],
#         [0.6723, 0.7506, 0.8610]], requires_grad=True)
# tensor(0.0011, grad_fn=<MseLossBackward0>)
# tensor([[0.1483, 0.2191, 0.3280],
#         [0.4034, 0.5327, 0.5980],
#         [0.6729, 0.7517, 0.8618]], requires_grad=True)
# tensor(0.0010, grad_fn=<MseLossBackward0>)
# tensor([[0.1472, 0.2187, 0.3274],
#         [0.4033, 0.5320, 0.5981],
#         [0.6735, 0.7527, 0.8627]], requires_grad=True)
# tensor(0.0010, grad_fn=<MseLossBackward0>)
# tensor([[0.1462, 0.2182, 0.3268],
#         [0.4033, 0.5312, 0.5981],
#         [0.6741, 0.7538, 0.8635]], requires_grad=True)
# tensor(0.0009, grad_fn=<MseLossBackward0>)
# tensor([[0.1451, 0.2178, 0.3262],
#         [0.4032, 0.5306, 0.5982],
#         [0.6747, 0.7548, 0.8643]], requires_grad=True)
# tensor(0.0009, grad_fn=<MseLossBackward0>)
# tensor([[0.1441, 0.2174, 0.3256],
#         [0.4031, 0.5299, 0.5982],
#         [0.6752, 0.7558, 0.8651]], requires_grad=True)
# tensor(0.0008, grad_fn=<MseLossBackward0>)
# tensor([[0.1432, 0.2171, 0.3251],
#         [0.4031, 0.5292, 0.5982],
#         [0.6758, 0.7568, 0.8659]], requires_grad=True)
# tensor(0.0008, grad_fn=<MseLossBackward0>)
# tensor([[0.1422, 0.2167, 0.3245],
#         [0.4030, 0.5286, 0.5983],
#         [0.6763, 0.7578, 0.8666]], requires_grad=True)
# tensor(0.0008, grad_fn=<MseLossBackward0>)
# tensor([[0.1413, 0.2163, 0.3240],
#         [0.4029, 0.5279, 0.5983],
#         [0.6768, 0.7587, 0.8674]], requires_grad=True)
# tensor(0.0007, grad_fn=<MseLossBackward0>)
# tensor([[0.1403, 0.2159, 0.3234],
#         [0.4029, 0.5273, 0.5984],
#         [0.6774, 0.7596, 0.8681]], requires_grad=True)
# tensor(0.0007, grad_fn=<MseLossBackward0>)
# tensor([[0.1395, 0.2156, 0.3229],
#         [0.4028, 0.5267, 0.5984],
#         [0.6779, 0.7605, 0.8688]], requires_grad=True)
# tensor(0.0007, grad_fn=<MseLossBackward0>)
# tensor([[0.1386, 0.2152, 0.3224],
#         [0.4027, 0.5261, 0.5984],
#         [0.6784, 0.7614, 0.8695]], requires_grad=True)
# tensor(0.0006, grad_fn=<MseLossBackward0>)
# tensor([[0.1377, 0.2149, 0.3219],
#         [0.4027, 0.5255, 0.5985],
#         [0.6788, 0.7623, 0.8702]], requires_grad=True)
# tensor(0.0006, grad_fn=<MseLossBackward0>)
# tensor([[0.1369, 0.2146, 0.3214],
#         [0.4026, 0.5250, 0.5985],
#         [0.6793, 0.7631, 0.8708]], requires_grad=True)
# tensor(0.0006, grad_fn=<MseLossBackward0>)
# tensor([[0.1361, 0.2142, 0.3209],
#         [0.4026, 0.5244, 0.5985],
#         [0.6798, 0.7639, 0.8715]], requires_grad=True)
# tensor(0.0006, grad_fn=<MseLossBackward0>)
# tensor([[0.1353, 0.2139, 0.3205],
#         [0.4025, 0.5239, 0.5986],
#         [0.6802, 0.7647, 0.8721]], requires_grad=True)
# tensor(0.0005, grad_fn=<MseLossBackward0>)
# tensor([[0.1345, 0.2136, 0.3200],
#         [0.4024, 0.5233, 0.5986],
#         [0.6807, 0.7655, 0.8727]], requires_grad=True)
# tensor(0.0005, grad_fn=<MseLossBackward0>)
# tensor([[0.1337, 0.2133, 0.3196],
#         [0.4024, 0.5228, 0.5986],
#         [0.6811, 0.7663, 0.8734]], requires_grad=True)
# tensor(0.0005, grad_fn=<MseLossBackward0>)
# tensor([[0.1330, 0.2130, 0.3191],
#         [0.4023, 0.5223, 0.5987],
#         [0.6815, 0.7670, 0.8739]], requires_grad=True)
# tensor(0.0005, grad_fn=<MseLossBackward0>)
# tensor([[0.1322, 0.2127, 0.3187],
#         [0.4023, 0.5218, 0.5987],
#         [0.6819, 0.7678, 0.8745]], requires_grad=True)
# tensor(0.0004, grad_fn=<MseLossBackward0>)
# tensor([[0.1315, 0.2125, 0.3183],
#         [0.4022, 0.5213, 0.5987],
#         [0.6823, 0.7685, 0.8751]], requires_grad=True)
# tensor(0.0004, grad_fn=<MseLossBackward0>)
# tensor([[0.1308, 0.2122, 0.3179],
#         [0.4022, 0.5209, 0.5987],
#         [0.6827, 0.7692, 0.8756]], requires_grad=True)
# tensor(0.0004, grad_fn=<MseLossBackward0>)
# tensor([[0.1301, 0.2119, 0.3175],
#         [0.4021, 0.5204, 0.5988],
#         [0.6831, 0.7699, 0.8762]], requires_grad=True)
# tensor(0.0004, grad_fn=<MseLossBackward0>)
# tensor([[0.1295, 0.2116, 0.3171],
#         [0.4021, 0.5199, 0.5988],
#         [0.6835, 0.7705, 0.8767]], requires_grad=True)
# tensor(0.0004, grad_fn=<MseLossBackward0>)
# tensor([[0.1288, 0.2114, 0.3167],
#         [0.4020, 0.5195, 0.5988],
#         [0.6838, 0.7712, 0.8772]], requires_grad=True)
# tensor(0.0004, grad_fn=<MseLossBackward0>)
# tensor([[0.1282, 0.2111, 0.3164],
#         [0.4020, 0.5191, 0.5988],
#         [0.6842, 0.7718, 0.8777]], requires_grad=True)
# tensor(0.0003, grad_fn=<MseLossBackward0>)
# tensor([[0.1275, 0.2109, 0.3160],
#         [0.4020, 0.5186, 0.5989],
#         [0.6845, 0.7724, 0.8782]], requires_grad=True)
# tensor(0.0003, grad_fn=<MseLossBackward0>)
# tensor([[0.1269, 0.2106, 0.3156],
#         [0.4019, 0.5182, 0.5989],
#         [0.6849, 0.7731, 0.8787]], requires_grad=True)
# tensor(0.0003, grad_fn=<MseLossBackward0>)
# tensor([[0.1263, 0.2104, 0.3153],
#         [0.4019, 0.5178, 0.5989],
#         [0.6852, 0.7737, 0.8792]], requires_grad=True)
# tensor(0.0003, grad_fn=<MseLossBackward0>)
# tensor([[0.1257, 0.2102, 0.3149],
#         [0.4018, 0.5174, 0.5989],
#         [0.6856, 0.7742, 0.8797]], requires_grad=True)
# tensor(0.0003, grad_fn=<MseLossBackward0>)
# tensor([[0.1252, 0.2099, 0.3146],
#         [0.4018, 0.5170, 0.5990],
#         [0.6859, 0.7748, 0.8801]], requires_grad=True)
# tensor(0.0003, grad_fn=<MseLossBackward0>)
# tensor([[0.1246, 0.2097, 0.3143],
#         [0.4017, 0.5167, 0.5990],
#         [0.6862, 0.7754, 0.8805]], requires_grad=True)
# tensor(0.0003, grad_fn=<MseLossBackward0>)
# tensor([[0.1241, 0.2095, 0.3140],
#         [0.4017, 0.5163, 0.5990],
#         [0.6865, 0.7759, 0.8810]], requires_grad=True)
# tensor(0.0003, grad_fn=<MseLossBackward0>)
# tensor([[0.1235, 0.2093, 0.3137],
#         [0.4017, 0.5159, 0.5990],
#         [0.6868, 0.7765, 0.8814]], requires_grad=True)
# tensor(0.0002, grad_fn=<MseLossBackward0>)
# tensor([[0.1230, 0.2091, 0.3134],
#         [0.4016, 0.5156, 0.5991],
#         [0.6871, 0.7770, 0.8818]], requires_grad=True)
# tensor(0.0002, grad_fn=<MseLossBackward0>)
# tensor([[0.1225, 0.2089, 0.3131],
#         [0.4016, 0.5152, 0.5991],
#         [0.6874, 0.7775, 0.8822]], requires_grad=True)
# tensor(0.0002, grad_fn=<MseLossBackward0>)
# tensor([[0.1220, 0.2087, 0.3128],
#         [0.4016, 0.5149, 0.5991],
#         [0.6877, 0.7780, 0.8826]], requires_grad=True)
# tensor(0.0002, grad_fn=<MseLossBackward0>)
# tensor([[0.1215, 0.2085, 0.3125],
#         [0.4015, 0.5146, 0.5991],
#         [0.6879, 0.7785, 0.8830]], requires_grad=True)
# tensor(0.0002, grad_fn=<MseLossBackward0>)
# tensor([[0.1210, 0.2083, 0.3122],
#         [0.4015, 0.5142, 0.5991],
#         [0.6882, 0.7790, 0.8834]], requires_grad=True)
# tensor(0.0002, grad_fn=<MseLossBackward0>)
# tensor([[0.1206, 0.2081, 0.3119],
#         [0.4015, 0.5139, 0.5992],
#         [0.6885, 0.7794, 0.8837]], requires_grad=True)
# tensor(0.0002, grad_fn=<MseLossBackward0>)
# tensor([[0.1201, 0.2079, 0.3117],
#         [0.4014, 0.5136, 0.5992],
#         [0.6887, 0.7799, 0.8841]], requires_grad=True)
# tensor(0.0002, grad_fn=<MseLossBackward0>)
# tensor([[0.1197, 0.2078, 0.3114],
#         [0.4014, 0.5133, 0.5992],
#         [0.6890, 0.7803, 0.8845]], requires_grad=True)
# tensor(0.0002, grad_fn=<MseLossBackward0>)
# tensor([[0.1192, 0.2076, 0.3112],
#         [0.4014, 0.5130, 0.5992],
#         [0.6892, 0.7808, 0.8848]], requires_grad=True)
# tensor(0.0002, grad_fn=<MseLossBackward0>)
# tensor([[0.1188, 0.2074, 0.3109],
#         [0.4013, 0.5127, 0.5992],
#         [0.6895, 0.7812, 0.8851]], requires_grad=True)
# tensor(0.0002, grad_fn=<MseLossBackward0>)
# tensor([[0.1184, 0.2073, 0.3107],
#         [0.4013, 0.5124, 0.5992],
#         [0.6897, 0.7816, 0.8855]], requires_grad=True)
# tensor(0.0001, grad_fn=<MseLossBackward0>)
# tensor([[0.1180, 0.2071, 0.3104],
#         [0.4013, 0.5122, 0.5993],
#         [0.6899, 0.7820, 0.8858]], requires_grad=True)
# tensor(0.0001, grad_fn=<MseLossBackward0>)
# tensor([[0.1176, 0.2069, 0.3102],
#         [0.4012, 0.5119, 0.5993],
#         [0.6901, 0.7824, 0.8861]], requires_grad=True)
# tensor(0.0001, grad_fn=<MseLossBackward0>)
# tensor([[0.1172, 0.2068, 0.3100],
#         [0.4012, 0.5116, 0.5993],
#         [0.6904, 0.7828, 0.8864]], requires_grad=True)
# tensor(0.0001, grad_fn=<MseLossBackward0>)
# tensor([[0.1168, 0.2066, 0.3098],
#         [0.4012, 0.5114, 0.5993],
#         [0.6906, 0.7832, 0.8867]], requires_grad=True)
# tensor(0.0001, grad_fn=<MseLossBackward0>)
# tensor([[0.1164, 0.2065, 0.3095],
#         [0.4012, 0.5111, 0.5993],
#         [0.6908, 0.7836, 0.8870]], requires_grad=True)
# tensor(0.0001, grad_fn=<MseLossBackward0>)
# tensor([[0.1161, 0.2063, 0.3093],
#         [0.4011, 0.5109, 0.5993],
#         [0.6910, 0.7839, 0.8873]], requires_grad=True)
# tensor(0.0001, grad_fn=<MseLossBackward0>)
# tensor([[0.1157, 0.2062, 0.3091],
#         [0.4011, 0.5106, 0.5994],
#         [0.6912, 0.7843, 0.8876]], requires_grad=True)
# tensor(0.0001, grad_fn=<MseLossBackward0>)
# tensor([[0.1154, 0.2061, 0.3089],
#         [0.4011, 0.5104, 0.5994],
#         [0.6914, 0.7846, 0.8879]], requires_grad=True)
# tensor(0.0001, grad_fn=<MseLossBackward0>)
# tensor([[0.1150, 0.2059, 0.3087],
#         [0.4011, 0.5102, 0.5994],
#         [0.6916, 0.7850, 0.8881]], requires_grad=True)
# tensor(9.7614e-05, grad_fn=<MseLossBackward0>)
# tensor([[0.1147, 0.2058, 0.3085],
#         [0.4010, 0.5099, 0.5994],
#         [0.6918, 0.7853, 0.8884]], requires_grad=True)
# tensor(9.3323e-05, grad_fn=<MseLossBackward0>)
# tensor([[0.1144, 0.2057, 0.3083],
#         [0.4010, 0.5097, 0.5994],
#         [0.6919, 0.7856, 0.8887]], requires_grad=True)
# tensor(8.9222e-05, grad_fn=<MseLossBackward0>)
# tensor([[0.1140, 0.2055, 0.3081],
#         [0.4010, 0.5095, 0.5994],
#         [0.6921, 0.7860, 0.8889]], requires_grad=True)
# tensor(8.5301e-05, grad_fn=<MseLossBackward0>)
# tensor([[0.1137, 0.2054, 0.3080],
#         [0.4010, 0.5093, 0.5994],
#         [0.6923, 0.7863, 0.8892]], requires_grad=True)
# tensor(8.1552e-05, grad_fn=<MseLossBackward0>)
# tensor([[0.1134, 0.2053, 0.3078],
#         [0.4010, 0.5091, 0.5995],
#         [0.6925, 0.7866, 0.8894]], requires_grad=True)
# tensor(7.7967e-05, grad_fn=<MseLossBackward0>)
# tensor([[0.1131, 0.2052, 0.3076],
#         [0.4009, 0.5089, 0.5995],
#         [0.6926, 0.7869, 0.8896]], requires_grad=True)
# tensor(7.4540e-05, grad_fn=<MseLossBackward0>)
# tensor([[0.1128, 0.2051, 0.3074],
#         [0.4009, 0.5087, 0.5995],
#         [0.6928, 0.7872, 0.8899]], requires_grad=True)
# tensor(7.1264e-05, grad_fn=<MseLossBackward0>)
# tensor([[0.1125, 0.2050, 0.3073],
#         [0.4009, 0.5085, 0.5995],
#         [0.6930, 0.7875, 0.8901]], requires_grad=True)
# tensor(6.8132e-05, grad_fn=<MseLossBackward0>)
# tensor([[0.1123, 0.2048, 0.3071],
#         [0.4009, 0.5083, 0.5995],
#         [0.6931, 0.7877, 0.8903]], requires_grad=True)
# tensor(6.5138e-05, grad_fn=<MseLossBackward0>)
# tensor([[0.1120, 0.2047, 0.3070],
#         [0.4008, 0.5081, 0.5995],
#         [0.6933, 0.7880, 0.8905]], requires_grad=True)
# tensor(6.2275e-05, grad_fn=<MseLossBackward0>)
# tensor([[0.1117, 0.2046, 0.3068],
#         [0.4008, 0.5079, 0.5995],
#         [0.6934, 0.7883, 0.8907]], requires_grad=True)
# tensor(5.9538e-05, grad_fn=<MseLossBackward0>)
# tensor([[0.1115, 0.2045, 0.3067],
#         [0.4008, 0.5078, 0.5995],
#         [0.6936, 0.7885, 0.8909]], requires_grad=True)
# tensor(5.6921e-05, grad_fn=<MseLossBackward0>)
# tensor([[0.1112, 0.2044, 0.3065],
#         [0.4008, 0.5076, 0.5995],
#         [0.6937, 0.7888, 0.8911]], requires_grad=True)
# tensor(5.4419e-05, grad_fn=<MseLossBackward0>)
# tensor([[0.1110, 0.2043, 0.3064],
#         [0.4008, 0.5074, 0.5996],
#         [0.6938, 0.7890, 0.8913]], requires_grad=True)
# tensor(5.2027e-05, grad_fn=<MseLossBackward0>)
# tensor([[0.1107, 0.2042, 0.3062],
#         [0.4008, 0.5073, 0.5996],
#         [0.6940, 0.7893, 0.8915]], requires_grad=True)
# tensor(4.9741e-05, grad_fn=<MseLossBackward0>)
# tensor([[0.1105, 0.2041, 0.3061],
#         [0.4007, 0.5071, 0.5996],
#         [0.6941, 0.7895, 0.8917]], requires_grad=True)
# tensor(4.7555e-05, grad_fn=<MseLossBackward0>)
# tensor([[0.1102, 0.2040, 0.3059],
#         [0.4007, 0.5069, 0.5996],
#         [0.6943, 0.7897, 0.8919]], requires_grad=True)
# tensor(4.5465e-05, grad_fn=<MseLossBackward0>)
# tensor([[0.1100, 0.2040, 0.3058],
#         [0.4007, 0.5068, 0.5996],
#         [0.6944, 0.7900, 0.8921]], requires_grad=True)
# tensor(4.3466e-05, grad_fn=<MseLossBackward0>)
# tensor([[0.1098, 0.2039, 0.3057],
#         [0.4007, 0.5066, 0.5996],
#         [0.6945, 0.7902, 0.8923]], requires_grad=True)
# tensor(4.1556e-05, grad_fn=<MseLossBackward0>)
# tensor([[0.1096, 0.2038, 0.3056],
#         [0.4007, 0.5065, 0.5996],
#         [0.6946, 0.7904, 0.8924]], requires_grad=True)
# tensor(3.9730e-05, grad_fn=<MseLossBackward0>)
# tensor([[0.1094, 0.2037, 0.3054],
#         [0.4007, 0.5063, 0.5996],
#         [0.6947, 0.7906, 0.8926]], requires_grad=True)
# tensor(3.7983e-05, grad_fn=<MseLossBackward0>)
# tensor([[0.1092, 0.2036, 0.3053],
#         [0.4006, 0.5062, 0.5996],
#         [0.6949, 0.7908, 0.8928]], requires_grad=True)
# tensor(3.6314e-05, grad_fn=<MseLossBackward0>)
# tensor([[0.1090, 0.2035, 0.3052],
#         [0.4006, 0.5061, 0.5996],
#         [0.6950, 0.7910, 0.8929]], requires_grad=True)
# tensor(3.4718e-05, grad_fn=<MseLossBackward0>)
# tensor([[0.1088, 0.2035, 0.3051],
#         [0.4006, 0.5059, 0.5996],
#         [0.6951, 0.7912, 0.8931]], requires_grad=True)
# tensor(3.3192e-05, grad_fn=<MseLossBackward0>)
# tensor([[0.1086, 0.2034, 0.3050],
#         [0.4006, 0.5058, 0.5997],
#         [0.6952, 0.7914, 0.8932]], requires_grad=True)
# tensor(3.1733e-05, grad_fn=<MseLossBackward0>)
# tensor([[0.1084, 0.2033, 0.3049],
#         [0.4006, 0.5057, 0.5997],
#         [0.6953, 0.7916, 0.8934]], requires_grad=True)
# tensor(3.0339e-05, grad_fn=<MseLossBackward0>)
# tensor([[0.1082, 0.2032, 0.3048],
#         [0.4006, 0.5055, 0.5997],
#         [0.6954, 0.7918, 0.8935]], requires_grad=True)
# tensor(2.9005e-05, grad_fn=<MseLossBackward0>)
# tensor([[0.1080, 0.2032, 0.3046],
#         [0.4006, 0.5054, 0.5997],
#         [0.6955, 0.7920, 0.8937]], requires_grad=True)
# tensor(2.7730e-05, grad_fn=<MseLossBackward0>)
# tensor([[0.1078, 0.2031, 0.3045],
#         [0.4006, 0.5053, 0.5997],
#         [0.6956, 0.7922, 0.8938]], requires_grad=True)
# tensor(2.6512e-05, grad_fn=<MseLossBackward0>)
# tensor([[0.1076, 0.2030, 0.3044],
#         [0.4005, 0.5052, 0.5997],
#         [0.6957, 0.7923, 0.8940]], requires_grad=True)
# tensor(2.5346e-05, grad_fn=<MseLossBackward0>)
# tensor([[0.1075, 0.2030, 0.3043],
#         [0.4005, 0.5051, 0.5997],
#         [0.6958, 0.7925, 0.8941]], requires_grad=True)
# tensor(2.4232e-05, grad_fn=<MseLossBackward0>)
# tensor([[0.1073, 0.2029, 0.3042],
#         [0.4005, 0.5049, 0.5997],
#         [0.6959, 0.7927, 0.8942]], requires_grad=True)
# tensor(2.3167e-05, grad_fn=<MseLossBackward0>)
# tensor([[0.1072, 0.2028, 0.3042],
#         [0.4005, 0.5048, 0.5997],
#         [0.6960, 0.7928, 0.8943]], requires_grad=True)
# tensor(2.2149e-05, grad_fn=<MseLossBackward0>)
# tensor([[0.1070, 0.2028, 0.3041],
#         [0.4005, 0.5047, 0.5997],
#         [0.6961, 0.7930, 0.8945]], requires_grad=True)
# tensor(2.1176e-05, grad_fn=<MseLossBackward0>)
# tensor([[0.1068, 0.2027, 0.3040],
#         [0.4005, 0.5046, 0.5997],
#         [0.6962, 0.7932, 0.8946]], requires_grad=True)
# tensor(2.0245e-05, grad_fn=<MseLossBackward0>)
# tensor([[0.1067, 0.2026, 0.3039],
#         [0.4005, 0.5045, 0.5997],
#         [0.6962, 0.7933, 0.8947]], requires_grad=True)
# tensor(1.9355e-05, grad_fn=<MseLossBackward0>)
# tensor([[0.1065, 0.2026, 0.3038],
#         [0.4005, 0.5044, 0.5997],
#         [0.6963, 0.7935, 0.8948]], requires_grad=True)
# tensor(1.8505e-05, grad_fn=<MseLossBackward0>)
# tensor([[0.1064, 0.2025, 0.3037],
#         [0.4005, 0.5043, 0.5997],
#         [0.6964, 0.7936, 0.8949]], requires_grad=True)
# tensor(1.7691e-05, grad_fn=<MseLossBackward0>)
# tensor([[0.1062, 0.2025, 0.3036],
#         [0.4004, 0.5042, 0.5997],
#         [0.6965, 0.7937, 0.8951]], requires_grad=True)
# tensor(1.6914e-05, grad_fn=<MseLossBackward0>)
# tensor([[0.1061, 0.2024, 0.3035],
#         [0.4004, 0.5041, 0.5998],
#         [0.6966, 0.7939, 0.8952]], requires_grad=True)
# tensor(1.6170e-05, grad_fn=<MseLossBackward0>)
# tensor([[0.1060, 0.2024, 0.3035],
#         [0.4004, 0.5040, 0.5998],
#         [0.6966, 0.7940, 0.8953]], requires_grad=True)
# tensor(1.5460e-05, grad_fn=<MseLossBackward0>)
# tensor([[0.1058, 0.2023, 0.3034],
#         [0.4004, 0.5040, 0.5998],
#         [0.6967, 0.7942, 0.8954]], requires_grad=True)
# tensor(1.4780e-05, grad_fn=<MseLossBackward0>)
# tensor([[0.1057, 0.2023, 0.3033],
#         [0.4004, 0.5039, 0.5998],
#         [0.6968, 0.7943, 0.8955]], requires_grad=True)
# tensor(1.4131e-05, grad_fn=<MseLossBackward0>)
# tensor([[0.1056, 0.2022, 0.3032],
#         [0.4004, 0.5038, 0.5998],
#         [0.6969, 0.7944, 0.8956]], requires_grad=True)
# tensor(1.3510e-05, grad_fn=<MseLossBackward0>)
# tensor([[0.1055, 0.2022, 0.3032],
#         [0.4004, 0.5037, 0.5998],
#         [0.6969, 0.7945, 0.8957]], requires_grad=True)
# tensor(1.2916e-05, grad_fn=<MseLossBackward0>)
# tensor([[0.1053, 0.2021, 0.3031],
#         [0.4004, 0.5036, 0.5998],
#         [0.6970, 0.7947, 0.8958]], requires_grad=True)
# tensor(1.2348e-05, grad_fn=<MseLossBackward0>)
# tensor([[0.1052, 0.2021, 0.3030],
#         [0.4004, 0.5035, 0.5998],
#         [0.6971, 0.7948, 0.8959]], requires_grad=True)
# tensor(1.1806e-05, grad_fn=<MseLossBackward0>)
# tensor([[0.1051, 0.2020, 0.3030],
#         [0.4004, 0.5035, 0.5998],
#         [0.6971, 0.7949, 0.8960]], requires_grad=True)
# tensor(1.1287e-05, grad_fn=<MseLossBackward0>)
# tensor([[0.1050, 0.2020, 0.3029],
#         [0.4004, 0.5034, 0.5998],
#         [0.6972, 0.7950, 0.8961]], requires_grad=True)
# tensor(1.0791e-05, grad_fn=<MseLossBackward0>)
# tensor([[0.1049, 0.2019, 0.3028],
#         [0.4003, 0.5033, 0.5998],
#         [0.6973, 0.7951, 0.8961]], requires_grad=True)
# tensor(1.0316e-05, grad_fn=<MseLossBackward0>)
# tensor([[0.1048, 0.2019, 0.3028],
#         [0.4003, 0.5032, 0.5998],
#         [0.6973, 0.7952, 0.8962]], requires_grad=True)
# tensor(9.8631e-06, grad_fn=<MseLossBackward0>)
